# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk
import scipy.stats as sc
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from ISLP import load_data
from ISLP.models import ModelSpec

# %%
rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = 2 * x + rng.normal(size=100)

# %%
df = pd.DataFrame({"x" : x, "y" : y})
formula = "y ~ x - 1"
model = ols(formula, df).fit()
print(model.params) #coef
print(model.bse) #SE
print(model.tvalues) #t-stat
print(model.pvalues) #p-val 

#B is pretty accurate because SE is pretty small
#Big t-stat -> higher probability of linear dependence
#P-value is small so dependence is linear
# Out:
# x    1.976242
# dtype: float64
# x    0.116948
# dtype: float64
# x    16.898417
# dtype: float64
# x    6.231546e-31
# dtype: float64

# %%
formula = "x ~ y - 1"
model = ols(formula, df).fit()
print(model.params) #coef
print(model.bse) #SE
print(model.tvalues) #t-stat
print(model.pvalues) #p-val

#T-statistic is the same for a simple linear regression without intercept
# Out:
# y    0.375744
# dtype: float64
# y    0.022235
# dtype: float64
# y    16.898417
# dtype: float64
# y    6.231546e-31
# dtype: float64
